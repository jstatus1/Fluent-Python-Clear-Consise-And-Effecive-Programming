# %% [markdown]
# # Numbers To Know

# %% [markdown]
# - When to shard a db
# - Whether to cache aggressively
# - How to handle large objects - these choices all depend on having an accurate sense of what's hardware can handle

# %% [markdown]
# # Modern Hardware Limits

# %% [markdown]
# - [AWS M6i.32xlarge EC2](https://aws.amazon.com/ec2/instance-types/m6i/)
#     - 512 GiB of memory and 128 vCPUs for general workloads
#     -
